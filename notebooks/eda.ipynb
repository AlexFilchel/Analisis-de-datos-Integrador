# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Estilo
sns.set(style="whitegrid")

# 1. Fatiga vs Performance
plt.figure()
sns.scatterplot(
    data=df,
    x="real_fatigue",
    y="performance_index",
    alpha=0.5
)
plt.title("Fatiga vs Performance")
plt.show()

# 2. Sueño vs Riesgo
plt.figure()
sns.boxplot(
    data=df,
    x="risk_level",
    y="sleep_hours"
)
plt.title("Horas de sueño según riesgo académico")
plt.show()

# 3. Pantalla vs Perfil
plt.figure()
sns.boxplot(
    data=df,
    x="student_profile",
    y="screen_time_hours"
)
plt.title("Tiempo de pantalla por perfil de estudiante")
plt.show()
